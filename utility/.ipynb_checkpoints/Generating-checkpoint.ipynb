# %% [markdown]
# <div style="position: relative;margin-top: 30px;">
#                 <img style="position: relative;display: inline-block;float: left; width: 150px;" src="zs-logo.jpg">
# </div>
# <div style = "background-color : white ; padding-left:20px; height : 30px">
# <h3 style = "padding:20px ; font-size : 30px ; font-family : Arial ; color:#E88B21"> PRIvacy preserving data SIMulator (PRISIM) </h3>
#
# </div>

# %% [markdown]
# ## <span style="color:orange"> Welcome to PRIvacy preserving data SIMulator (PRISIM)Toolkit - Part 2 </span>
#
#
# In this phase, we will use the previously trained and saved generative model to generate a synthetic version of the specific data and run a privacy engine on top of it to ensure the final dataset prevents information leakage while retaining the analytical utility for ML tasks.

# %% [markdown]
# <br>
# <img src = flow22.png style='width=100px; height:100px'>

# %%
# from IPython.core.display import display, HTML, Javascript
# display(HTML("<style>.container { width:80% !important; }</style>"))
# display(HTML('''
# <style>
# div#site{
# height: 100% !important
# }
# </style>
# '''))
# display(Javascript("""
# $([IPython.events]).on('notebook_loaded.Notebook', function(){
#     $('#header').hide();

#     IPython.keyboard_manager.command_shortcuts.add_shortcut('ctrl-`', function (event) {
#         if (IPython.notebook.mode == 'command') {
#             $('#header').toggle();
#             return false;
#         }
#         return true;
#     });
# });
# """))

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import os
import sys
path = os.path.join(os.path.dirname(os.path.realpath('__file__')), os.pardir)
sys.path.append(path)
from privacy.app import dataPrivacy
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

javascript_functions = {False: "hide()", True: "show()"}
button_descriptions  = {False: "Click to run this section!", True: "Hide code"}

app = dataPrivacy()
def toggle_code(state):

    """
    Toggles the JavaScript show()/hide() function on the div.input element.
    """

    output_string = "<script>$(\"div.input\").{}</script>"
    output_args   = (javascript_functions[state],)
    output        = output_string.format(*output_args)
    
    display(HTML(output))


def button_action(value):

    """
    Calls the toggle_code function and updates the button description.
    """
    clear_output()
#     display(button)
    app.loadModelGenerateData()

state = False
toggle_code(state)

button = widgets.ToggleButton(state, description = button_descriptions[state], button_style='primary', layout={'width': 'auto'})
button.observe(button_action, "value")
app.loadModelGenerateData()
# display(button)
# Out:
# This is DEMO version of PRISM (Synthetic Data Generation and Privacy Tool
# Copyright ZS: All the files assocaited with PRISM are use for DEMO purposes. No part of the code/notebooks are to be circulated, quoted or reproduced for distribution without prior written approval from ZS
# <script>$("div.input").hide()</script>
# <h2 id="-2.1-Model-Uploading-"><span style="color:orange"> 2.1 Model Uploading </span>
#                     <a class="anchor-link" href="#-2.1-Model-Uploading-">¶</a>
#                     </h2>
# <details>
# <summary><b> &lt;&lt;  CLICK HERE to expand / collapse Section Overview &gt;&gt; </b></summary>
#
# <h3 id="-2.-Private-Synthetic-Data-Generation-pipeline-:-"><span style="color:indigo"> 2. Private Synthetic Data Generation pipeline : </span><a class="anchor-link" href="#-2.-Private-Synthetic-Data-Generation-pipeline-:-">¶</a></h3>
# <ul>
# <li><input checked="" disabled="disabled" type="checkbox"> <span style="color:green"> Loading the saved generative model from the Training phase. </span></li>
# <li><input disabled="disabled" type="checkbox"> Private Data Generation</li>
# <li><input disabled="disabled" type="checkbox"> EDA on the Private Data</li>
# </ul>
# <p>In this step we simply load a previously trained and saved model to be used for the following steps of data generation and privatization. </p>
# <p>To run this section:</p>
# <ol>
# <li>Provide the <code>.pkl</code> model file path and click <code>Import Model</code> button.</li>
# <li>A message <code>Model Loaded successfully !</code> along with details of the loaded model (model type, which dataset was it trained on, size of the data and total features) will be displayed on success.</li></ol></details>
# HBox(children=(Text(value='', description='<b>Model Path:</b>', layout=Layout(width='70%'), placeholder='Enter…
# HBox(children=(Output(),), layout=Layout(align_items='stretch', display='flex', flex_flow='column', width='100…
