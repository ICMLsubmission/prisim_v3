# %%
# !pip install pgeocode
# !pip install -U jupyterlab ipywidgets jupyterlab-widgets

# !pip install jupyterlab_widgets

# !pip install ipywidgets
# !pip install jupyter_core>=4.12

# !pip install importlib_metadata>=6.0

# %%
# !git clone https://github.com/ICMLsubmission/prisim_v3.git
# %cd prisim_v3
# # # !pip install pgeocode
# # !pip install faker
# Out:
# Cloning into 'prisim_v3'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 187 (delta 32), reused 176 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (187/187), 39.91 MiB | 17.40 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# Updating files: 100% (162/162), done.
# /content/prisim_v3/prisim_v3/prisim_v3/prisim_v3/prisim_v3

# %%
# !pip install "ctgan>=0.10.0"

# %%
# # Clone repo
# !git clone https://github.com/ICMLsubmission/prisim_v3.git
# %cd prisim_v3

# # Install all other deps but ignore errors
# !pip install -r requirements.txt || true

# # Install OLD CTGAN compatible with your code
# !pip install ctgan==0.2.1

# # Fix paths
# import sys, os
# sys.path.append(os.getcwd())
# Out:
# Cloning into 'prisim_v3'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 187 (delta 32), reused 176 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (187/187), 39.91 MiB | 13.31 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# Updating files: 100% (162/162), done.
# /content/prisim_v3/prisim_v3/prisim_v3/prisim_v3/prisim_v3/prisim_v3
# ERROR: Ignored the following versions that require a different python version: 0.2.2 Requires-Python >=3.6,<3.9; 0.2.2.dev1 Requires-Python >=3.5,<3.9; 0.2.2.dev2 Requires-Python >=3.6,<3.9; 0.2.2.dev3 Requires-Python >=3.6,<3.9; 0.3.0 Requires-Python >=3.6,<3.9; 0.3.0.dev0 Requires-Python >=3.5,<3.9; 0.3.0.dev1 Requires-Python >=3.6,<3.9; 0.3.1 Requires-Python >=3.6,<3.9; 0.3.1.dev0 Requires-Python >=3.6,<3.9; 0.3.1.dev1 Requires-Python >=3.6,<3.9; 0.3.1.dev2 Requires-Python >=3.6,<3.9; 0.3.2.dev0 Requires-Python >=3.6,<3.9; 0.4.0 Requires-Python >=3.6,<3.9; 0.4.0.dev0 Requires-Python >=3.6,<3.9; 0.4.0.dev1 Requires-Python >=3.6,<3.9; 0.4.1 Requires-Python >=3.6,<3.9; 0.4.1.dev0 Requires-Python >=3.6,<3.9; 0.4.1.dev1 Requires-Python >=3.6,<3.9; 0.4.2 Requires-Python >=3.6,<3.9; 0.4.2.dev0 Requires-Python >=3.6,<3.9; 0.4.3 Requires-Python >=3.6,<3.9; 0.4.3.dev0 Requires-Python >=3.6,<3.9; 0.4.3.dev1 Requires-Python >=3.6,<3.9; 0.4.4.dev0 Requires-Python >=3.6,<3.9; 0.5.0 Requires-Python >=3.6,<3.10; 0.5.0.dev0 Requires-Python >=3.6,<3.9; 0.5.0.dev1 Requires-Python >=3.6,<3.10; 0.5.1 Requires-Python >=3.6,<3.10; 0.5.1.dev0 Requires-Python >=3.6,<3.10; 0.5.1.dev1 Requires-Python >=3.6,<3.10; 0.5.1.dev2 Requires-Python >=3.6,<3.10; 0.5.1.dev3 Requires-Python >=3.6,<3.10; 0.5.2 Requires-Python >=3.6,<3.10; 0.5.2.dev0 Requires-Python >=3.6,<3.10; 0.5.2.dev1 Requires-Python >=3.6,<3.10; 0.5.3.dev0 Requires-Python >=3.6,<3.10; 0.6.0 Requires-Python >=3.6,<3.10; 0.6.0.dev0 Requires-Python >=3.6,<3.10; 0.7.0 Requires-Python >=3.7,<3.11; 0.7.0.dev0 Requires-Python >=3.7,<3.11; 0.7.1 Requires-Python >=3.7,<3.11; 0.7.1.dev0 Requires-Python >=3.7,<3.11; 0.7.2 Requires-Python >=3.7,<3.11; 0.7.2.dev0 Requires-Python >=3.7,<3.11; 0.7.2.dev1 Requires-Python >=3.7,<3.11; 0.7.3 Requires-Python >=3.7,<3.11; 0.7.3.dev0 Requires-Python >=3.7,<3.11; 0.7.4 Requires-Python >=3.8,<3.12; 0.7.4.dev0 Requires-Python >=3.8,<3.12; 0.7.5 Requires-Python >=3.8,<3.12; 0.7.5.dev0 Requires-Python >=3.8,<3.12; 0.8.0 Requires-Python >=3.8,<3.12; 0.8.0.dev0 Requires-Python >=3.8,<3.12; 0.9.0 Requires-Python >=3.8,<3.12; 0.9.0.dev0 Requires-Python >=3.8,<3.12; 0.9.1 Requires-Python <3.12,>=3.8; 0.9.1.dev0 Requires-Python <3.12,>=3.8
# ERROR: Could not find a version that satisfies the requirement ctgan==0.5.1 (from versions: 0.1.0.dev0, 0.1.0, 0.2.0.dev0, 0.2.0, 0.2.1.dev0, 0.2.1, 0.2.2.dev0, 0.10.0.dev0, 0.10.0, 0.10.1.dev0, 0.10.1, 0.10.2.dev0, 0.10.2, 0.11.0.dev0, 0.11.0, 0.11.1.dev0, 0.11.1, 0.11.2.dev0, 0.12.0, 0.12.1.dev0, 0.12.1)
# ERROR: No matching distribution found for ctgan==0.5.1
# Collecting ctgan==0.2.1
#   Using cached ctgan-0.2.1-py2.py3-none-any.whl.metadata (11 kB)
# INFO: pip is looking at multiple versions of ctgan to determine which version is compatible with other requirements. This could take a while.
# ERROR: Ignored the following versions that require a different python version: 0.2.2 Requires-Python >=3.6,<3.9; 0.2.2.dev1 Requires-Python >=3.5,<3.9; 0.2.2.dev2 Requires-Python >=3.6,<3.9; 0.2.2.dev3 Requires-Python >=3.6,<3.9; 0.3.0 Requires-Python >=3.6,<3.9; 0.3.0.dev0 Requires-Python >=3.5,<3.9; 0.3.0.dev1 Requires-Python >=3.6,<3.9; 0.3.1 Requires-Python >=3.6,<3.9; 0.3.1.dev0 Requires-Python >=3.6,<3.9; 0.3.1.dev1 Requires-Python >=3.6,<3.9; 0.3.1.dev2 Requires-Python >=3.6,<3.9; 0.3.2.dev0 Requires-Python >=3.6,<3.9; 0.4.0 Requires-Python >=3.6,<3.9; 0.4.0.dev0 Requires-Python >=3.6,<3.9; 0.4.0.dev1 Requires-Python >=3.6,<3.9; 0.4.1 Requires-Python >=3.6,<3.9; 0.4.1.dev0 Requires-Python >=3.6,<3.9; 0.4.1.dev1 Requires-Python >=3.6,<3.9; 0.4.2 Requires-Python >=3.6,<3.9; 0.4.2.dev0 Requires-Python >=3.6,<3.9; 0.4.3 Requires-Python >=3.6,<3.9; 0.4.3.dev0 Requires-Python >=3.6,<3.9; 0.4.3.dev1 Requires-Python >=3.6,<3.9; 0.4.4.dev0 Requires-Python >=3.6,<3.9; 0.5.0 Requires-Python >=3.6,<3.10; 0.5.0.dev0 Requires-Python >=3.6,<3.9; 0.5.0.dev1 Requires-Python >=3.6,<3.10; 0.5.1 Requires-Python >=3.6,<3.10; 0.5.1.dev0 Requires-Python >=3.6,<3.10; 0.5.1.dev1 Requires-Python >=3.6,<3.10; 0.5.1.dev2 Requires-Python >=3.6,<3.10; 0.5.1.dev3 Requires-Python >=3.6,<3.10; 0.5.2 Requires-Python >=3.6,<3.10; 0.5.2.dev0 Requires-Python >=3.6,<3.10; 0.5.2.dev1 Requires-Python >=3.6,<3.10; 0.5.3.dev0 Requires-Python >=3.6,<3.10; 0.6.0 Requires-Python >=3.6,<3.10; 0.6.0.dev0 Requires-Python >=3.6,<3.10; 0.7.0 Requires-Python >=3.7,<3.11; 0.7.0.dev0 Requires-Python >=3.7,<3.11; 0.7.1 Requires-Python >=3.7,<3.11; 0.7.1.dev0 Requires-Python >=3.7,<3.11; 0.7.2 Requires-Python >=3.7,<3.11; 0.7.2.dev0 Requires-Python >=3.7,<3.11; 0.7.2.dev1 Requires-Python >=3.7,<3.11; 0.7.3 Requires-Python >=3.7,<3.11; 0.7.3.dev0 Requires-Python >=3.7,<3.11; 0.7.4 Requires-Python >=3.8,<3.12; 0.7.4.dev0 Requires-Python >=3.8,<3.12; 0.7.5 Requires-Python >=3.8,<3.12; 0.7.5.dev0 Requires-Python >=3.8,<3.12; 0.8.0 Requires-Python >=3.8,<3.12; 0.8.0.dev0 Requires-Python >=3.8,<3.12; 0.9.0 Requires-Python >=3.8,<3.12; 0.9.0.dev0 Requires-Python >=3.8,<3.12; 0.9.1 Requires-Python <3.12,>=3.8; 0.9.1.dev0 Requires-Python <3.12,>=3.8
# ERROR: Could not find a version that satisfies the requirement torch<2,>=1.0 (from ctgan) (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0)
# ERROR: No matching distribution found for torch<2,>=1.0

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# <div style="position: relative;margin-top: 30px;">
#                 <img style="position: relative;display: inline-block;float: left; width: 150px;" src="https://github.com/ICMLsubmission/prisim_v3/blob/main/utility/zs-logo.jpg?raw=1">
# </div>
# <div style = "background-color : white ; padding-left:20px; height : 30px">
# <h3 style = "padding:20px ; font-size : 30px ; font-family : Arial ; color:#E88B21"> PRIvacy preserving data SIMulator (PRISIM) </h3>
#
# </div>

# %% [markdown]
# ## <span style="color:orange"> Welcome to PRIvacy preserving data SIMulator (PRISIM)Toolkit - Part 3 </span>
#
# This toolkit enables the user to pseudonymize their sensitive cross-sectional dataset by adopting advanced data-type specific privacy preserving mechanisms.

# %% [markdown]
# <br>
# <img src = flow3.png style='width=100px; height:150px'>

# %%
import os
import sys
path = os.path.join(os.path.dirname(os.path.realpath('__file__')), os.pardir)
sys.path.append(path)
from privacy.app import *
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output
from ipywidgets import widgets, ButtonStyle


javascript_functions = {False: "hide()", True: "show()"}
button_descriptions  = {False: "Click to run this section!", True: "Hide code"}

app = dataPrivacy()
def toggle_code(state):

    """
    Toggles the JavaScript show()/hide() function on the div.input element.
    """

    output_string = "<script>$(\"div.input\").{}</script>"
    output_args   = (javascript_functions[state],)
    output        = output_string.format(*output_args)

    display(HTML(output))


def button_action(value):

    """
    Calls the toggle_code function and updates the button description.
    """
    clear_output()
#     display(button)
    app.dataReading()


state = False
toggle_code(state)

button = widgets.ToggleButton(state, description = button_descriptions[state], button_style='primary', layout={'width': 'auto'})
button.observe(button_action, "value")
app.dataReading(psuedoMode=True)
# display(button)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_770/514460749.py in <cell line: 0>()
#       3 path = os.path.join(os.path.dirname(os.path.realpath('__file__')), os.pardir)
#       4 sys.path.append(path)
# ----> 5 from privacy.app import *
#       6 import ipywidgets as widgets
#       7 from IPython.display import display, HTML, clear_output
#
# /content/prisim_v3/privacy/app.py in <module>
#       3 import traceback
#       4 from .src.config import Config
# ----> 5 from .design.file_upload import fileUpload
#       6 from .design.data_processing import dataProcessing
#       7 from .design.reporting import dataProfiling
#
# /content/prisim_v3/privacy/design/file_upload.py in <module>
#       2 from ..src.data_handling import dataReading
#       3 from .html_codes import datasetuploading_html_codes, psuedo_datasetuploading_html_codes
# ----> 4 from .data_processing import dataProcessing
#       5 from ipywidgets import widgets, Layout, ButtonStyle
#       6 from IPython.display import HTML, display, clear_output
#
# /content/prisim_v3/privacy/design/data_processing.py in <module>
#      12 from .pseudonymization_fe import pseudonymization
#      13 from .reporting import dataProfiling
# ---> 14 from .training_generation_fe import trainingGeneration
#      15
#      16 def get_discarded_values(data):
#
# /content/prisim_v3/privacy/design/training_generation_fe.py in <module>
#      13 from ipywidgets import widgets, ButtonStyle, Layout
#      14 from IPython.display import HTML, display, clear_output
# ---> 15 from ..src.synthetic_data_gen import trainModel
#      16 from ..src.config import Config
#      17 from .html_codes import model_description_header
#
# /content/prisim_v3/privacy/src/synthetic_data_gen.py in <module>
#      11
#      12 # from .synthesizers.ctgan_dp import CTGANSynthesizer
# ---> 13 from .custom_models.synthesizers.ctgan import CTGANSynthesizer
#      14 from .custom_models.synthesizers.tvae import TVAESynthesizer
#      15 from sdv.tabular import GaussianCopula
#
# /content/prisim_v3/privacy/src/custom_models/synthesizers/__init__.py in <module>
#       1 """Synthesizers module."""
#       2
# ----> 3 from ctgan.synthesizers.ctgan import CTGANSynthesizer
#       4 from ctgan.synthesizers.tvae import TVAESynthesizer
#       5
#
# ImportError: cannot import name 'CTGANSynthesizer' from 'ctgan.synthesizers.ctgan' (/usr/local/lib/python3.12/dist-packages/ctgan/synthesizers/ctgan.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
